# %%
import subprocess
result = subprocess.run(['pip', 'list'], capture_output=True, text=True)
print(result.stdout)
# Out:
# Package            Version
# ------------------ -----------
# annotated-doc      0.0.3
# annotated-types    0.7.0
# anyio              4.11.0
# appnope            0.1.4
# asttokens          3.0.0
# click              8.1.8
# comm               0.2.3
# debugpy            1.8.17
# decorator          5.2.1
# exceptiongroup     1.3.0
# executing          2.2.1
# fastapi            0.121.0
# h11                0.16.0
# idna               3.11
# importlib_metadata 8.7.0
# ipykernel          6.31.0
# ipython            8.18.1
# jedi               0.19.2
# jupyter_client     8.6.3
# jupyter_core       5.8.1
# matplotlib-inline  0.2.1
# nest-asyncio       1.6.0
# packaging          25.0
# parso              0.8.5
# pexpect            4.9.0
# pip                25.3
# platformdirs       4.4.0
# prompt_toolkit     3.0.52
# psutil             7.1.3
# psycopg2-binary    2.9.11
# ptyprocess         0.7.0
# pure_eval          0.2.3
# pydantic           2.12.3
# pydantic_core      2.41.4
# Pygments           2.19.2
# python-dateutil    2.9.0.post0
# python-dotenv      1.2.1
# pyzmq              27.1.0
# setuptools         58.0.4
# six                1.17.0
# sniffio            1.3.1
# SQLAlchemy         2.0.44
# stack-data         0.6.3
# starlette          0.49.3
# tornado            6.5.2
# traitlets          5.14.3
# typing_extensions  4.15.0
# typing-inspection  0.4.2
# uvicorn            0.38.0
# wcwidth            0.2.14
# zipp               3.23.0

# %%
# Test all imports
import sys
print("Python location:", sys.executable)
print()

# Try importing required packages
packages = ['pandas', 'numpy', 'matplotlib', 'jupyter']

print("Checking packages:")
print("-" * 40)

for package in packages:
    try:
        __import__(package)
        print(f"✓ {package:15s} - Installed")
    except ImportError:
        print(f"✗ {package:15s} - NOT FOUND")

print()
print("If all show ✓, you're ready!")
# Out:
# Python location: /Users/chinchunggan/Coding/food-decider/.venv/bin/python
#
# Checking packages:
# ----------------------------------------
# ✗ pandas          - NOT FOUND
# ✗ numpy           - NOT FOUND
# ✗ matplotlib      - NOT FOUND
# ✓ jupyter         - Installed
#
# If all show ✓, you're ready!

# %%
import sys
print(sys.executable)
# Out:
# /Users/chinchunggan/Coding/food-decider/.venv/bin/python
